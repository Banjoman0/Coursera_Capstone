# %% [markdown]
# # Applied Data Science Capstone -- Week 3
# ## Segmenting and Clustering Neighborhoods in Toronto -- Part 1
#
# First, import the data table into a dataframe:

# %%
import pandas as pd

data1 = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]
data1.head(10)
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront
# 5      M5A  Downtown Toronto       Regent Park
# 6      M6A        North York  Lawrence Heights
# 7      M6A        North York    Lawrence Manor
# 8      M7A      Queen's Park      Not assigned
# 9      M8A      Not assigned      Not assigned

# %% [markdown]
# Remove records where a Borough is not assigned to a Postcode:

# %%
data1.drop(index=data1.loc[data1['Borough']=='Not assigned'].index, inplace=True)  # remove postcodes not assigned
data1.reset_index(inplace=True)  # reindex remaining entries
data1.drop(columns='index', inplace=True)  # remove extra index column
data1.head(10)
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M3A        North York         Parkwoods
# 1      M4A        North York  Victoria Village
# 2      M5A  Downtown Toronto      Harbourfront
# 3      M5A  Downtown Toronto       Regent Park
# 4      M6A        North York  Lawrence Heights
# 5      M6A        North York    Lawrence Manor
# 6      M7A      Queen's Park      Not assigned
# 7      M9A         Etobicoke  Islington Avenue
# 8      M1B       Scarborough             Rouge
# 9      M1B       Scarborough           Malvern

# %% [markdown]
# If Neighborhood is not assigned, rename to Borough name:

# %%
renamelist=data1.loc[data1['Neighbourhood']=='Not assigned'].index
data1.iloc[renamelist,2]=data1.iloc[renamelist,1]  # for each neighborhood not assigned, rename to Borough
data1.head(10)
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M3A        North York         Parkwoods
# 1      M4A        North York  Victoria Village
# 2      M5A  Downtown Toronto      Harbourfront
# 3      M5A  Downtown Toronto       Regent Park
# 4      M6A        North York  Lawrence Heights
# 5      M6A        North York    Lawrence Manor
# 6      M7A      Queen's Park      Queen's Park
# 7      M9A         Etobicoke  Islington Avenue
# 8      M1B       Scarborough             Rouge
# 9      M1B       Scarborough           Malvern

# %% [markdown]
# If a Postcode contains multiple neighborhoods, combine them into the first postcode entry and then remove duplicate postcode entries

# %%
data1['Dupes']=data1.duplicated(subset='Postcode') #identify duplicate Postcodes

for i in data1.index:
    if not data1.iloc[i,3]:  # if Dupes=False, advance, keeping track if it is first duplicate entry
        k=i
    else:
        data1.iloc[k,2]=data1.iloc[k,2]+', '+data1.iloc[i,2]  #if Dupes=True, append neighborhood indo first duplicate entry
    
data1.drop(index=data1.loc[data1['Dupes']].index, inplace=True)  #remove the duplicate entries and reindex
data1.reset_index(inplace=True)
data1.drop(columns=['index','Dupes'], inplace=True)  #remove extra columns
data1.head(20)
# Out:
#    Postcode           Borough  \
# 0       M3A        North York
# 1       M4A        North York
# 2       M5A  Downtown Toronto
# 3       M6A        North York
# 4       M7A      Queen's Park
# 5       M9A         Etobicoke
# 6       M1B       Scarborough
# 7       M3B        North York
# 8       M4B         East York
# 9       M5B  Downtown Toronto
# 10      M6B        North York
# 11      M9B         Etobicoke
# 12      M1C       Scarborough
# 13      M3C        North York
# 14      M4C         East York
# 15      M5C  Downtown Toronto
# 16      M6C              York
# 17      M9C         Etobicoke
# 18      M1E       Scarborough
# 19      M4E      East Toronto
#
#                                         Neighbourhood
# 0                                           Parkwoods
# 1                                    Victoria Village
# 2                           Harbourfront, Regent Park
# 3                    Lawrence Heights, Lawrence Manor
# 4                                        Queen's Park
# 5                                    Islington Avenue
# 6                                      Rouge, Malvern
# 7                                     Don Mills North
# 8                     Woodbine Gardens, Parkview Hill
# 9                            Ryerson, Garden District
# 10                                          Glencairn
# 11  Cloverdale, Islington, Martin Grove, Princess ...
# 12             Highland Creek, Rouge Hill, Port Union
# 13                   Flemingdon Park, Don Mills South
# 14                                   Woodbine Heights
# 15                                     St. James Town
# 16                                 Humewood-Cedarvale
# 17  Bloordale Gardens, Eringate, Markland Wood, Ol...
# 18                  Guildwood, Morningside, West Hill
# 19                                        The Beaches

# %% [markdown]
# Print number of rows in dataframe

# %%
print("Number of rows in Postcode dataframe:  " + str(data1.shape[0]))
# Out:
# Number of rows in Postcode dataframe:  103

# %% [markdown]
# ## Segmenting and Clustering Neighborhoods in Toronto -- Part 2

# %% [markdown]
# Try to get the latitude and the longitude coordinates of each Postcode using geocoder

# %%
import geocoder   # import the geocoder module

# initialize collectors for latitudes and longitudes
lats=[]
longs=[]
codes=[]
for i in data1.index:
    latlong_coords=None
    # loop until you get the coordinates
    k=0    # put a limit on how many requests for each borough
    while((latlong_coords is None) and (k<20) ):
        k+=1
        # use the geocode farm instead of google, since google is denying requests
        g = geocoder.geocodefarm('{}, Toronto, Ontario'.format(data1.iloc[i,0]))
        latlong_coords = g.latlng

    print(i,k, data1.iloc[i,0], g)
    codes.append(data1.iloc[i,0])
    lats.append(latlong_coords[0])
    longs.append(latlong_coords[1])
    
# create a new dataframe with coordinates and merge with neighborhoods dataframe
d={'Postcode':codes, 'Latitude':lats, 'Longitude':longs}
pcodes2=pd.DataFrame(data=d)
gdata2 = data1.merge(pcodes2, on="Postcode")
gdata2.head(20)
# Out:
# 0 3 M3A <[OK] Geocodefarm - Geocode [M3A, ON, Canada]>
# 1 1 M4A <[OK] Geocodefarm - Geocode [M4A, ON, Canada]>
# 2 3 M5A <[OK] Geocodefarm - Geocode [M5A, ON, Canada]>
# 3 2 M6A <[OK] Geocodefarm - Geocode [M6A, ON, Canada]>
# 4 1 M7A <[OK] Geocodefarm - Geocode [M7A, ON, Canada]>
# 5 3 M9A <[OK] Geocodefarm - Geocode [M9A, ON, Canada]>
# 6 1 M1B <[OK] Geocodefarm - Geocode [M1B, ON, Canada]>
# 7 1 M3B <[OK] Geocodefarm - Geocode [M3B, ON, Canada]>
# 8 4 M4B <[OK] Geocodefarm - Geocode [M4B, ON, Canada]>
# 9 5 M5B <[OK] Geocodefarm - Geocode [M5B, ON, Canada]>
# 10 1 M6B <[OK] Geocodefarm - Geocode [M6B, ON, Canada]>
# 11 3 M9B <[OK] Geocodefarm - Geocode [M9B, ON, Canada]>
# 12 4 M1C <[OK] Geocodefarm - Geocode [M1C, ON, Canada]>
# 13 1 M3C <[OK] Geocodefarm - Geocode [M3C, ON, Canada]>
# 14 3 M4C <[OK] Geocodefarm - Geocode [M4C, ON, Canada]>
# 15 1 M5C <[OK] Geocodefarm - Geocode [M5C, ON, Canada]>
# 16 1 M6C <[OK] Geocodefarm - Geocode [M6C, ON, Canada]>
# 17 1 M9C <[OK] Geocodefarm - Geocode [M9C, ON, Canada]>
# 18 1 M1E <[OK] Geocodefarm - Geocode [M1E, ON, Canada]>
# 19 4 M4E <[OK] Geocodefarm - Geocode [M4E, ON, Canada]>
# 20 1 M5E <[OK] Geocodefarm - Geocode [M5E, ON, Canada]>
# 21 2 M6E <[OK] Geocodefarm - Geocode [M6E, ON, Canada]>
# 22 1 M1G <[OK] Geocodefarm - Geocode [M1G, ON, Canada]>
# 23 2 M4G <[OK] Geocodefarm - Geocode [M4G, ON, Canada]>
# 24 1 M5G <[OK] Geocodefarm - Geocode [M5G, ON, Canada]>
# 25 1 M6G <[OK] Geocodefarm - Geocode [M6G, ON, Canada]>
# 26 1 M1H <[OK] Geocodefarm - Geocode [M1H, ON, Canada]>
# 27 2 M2H <[OK] Geocodefarm - Geocode [M2H, ON, Canada]>
# 28 1 M3H <[OK] Geocodefarm - Geocode [M3H, ON, Canada]>
# 29 1 M4H <[OK] Geocodefarm - Geocode [M4H, ON, Canada]>
# 30 1 M5H <[OK] Geocodefarm - Geocode [M5H, ON, Canada]>
# 31 1 M6H <[OK] Geocodefarm - Geocode [M6H, ON, Canada]>
# 32 1 M1J <[OK] Geocodefarm - Geocode [M1J, ON, Canada]>
# 33 1 M2J <[OK] Geocodefarm - Geocode [M2J, ON, Canada]>
# 34 4 M3J <[OK] Geocodefarm - Geocode [M3J, ON, Canada]>
# 35 2 M4J <[OK] Geocodefarm - Geocode [M4J, ON, Canada]>
# 36 2 M5J <[OK] Geocodefarm - Geocode [M5J, ON, Canada]>
# 37 3 M6J <[OK] Geocodefarm - Geocode [M6J, ON, Canada]>
# 38 1 M1K <[OK] Geocodefarm - Geocode [M1K, ON, Canada]>
# 39 2 M2K <[OK] Geocodefarm - Geocode [M2K, ON, Canada]>
# 40 2 M3K <[OK] Geocodefarm - Geocode [M3K, ON, Canada]>
# 41 1 M4K <[OK] Geocodefarm - Geocode [M4K, ON, Canada]>
# 42 1 M5K <[OK] Geocodefarm - Geocode [M5K, ON, Canada]>
# 43 1 M6K <[OK] Geocodefarm - Geocode [M6K, ON, Canada]>
# 44 4 M1L <[OK] Geocodefarm - Geocode [M1L, ON, Canada]>
# 45 1 M2L <[OK] Geocodefarm - Geocode [M2L, ON, Canada]>
# 46 2 M3L <[OK] Geocodefarm - Geocode [M3L, ON, Canada]>
# 47 2 M4L <[OK] Geocodefarm - Geocode [M4L, ON, Canada]>
# 48 1 M5L <[OK] Geocodefarm - Geocode [M5L, ON, Canada]>
# 49 1 M6L <[OK] Geocodefarm - Geocode [M6L, ON, Canada]>
# 50 1 M9L <[OK] Geocodefarm - Geocode [M9L, ON, Canada]>
# 51 3 M1M <[OK] Geocodefarm - Geocode [M1M, ON, Canada]>
# 52 7 M2M <[OK] Geocodefarm - Geocode [M2M, ON, Canada]>
# 53 1 M3M <[OK] Geocodefarm - Geocode [M3M, ON, Canada]>
# 54 4 M4M <[OK] Geocodefarm - Geocode [M4M, ON, Canada]>
# 55 3 M5M <[OK] Geocodefarm - Geocode [M5M, ON, Canada]>
# 56 7 M6M <[OK] Geocodefarm - Geocode [M6M, ON, Canada]>
# 57 1 M9M <[OK] Geocodefarm - Geocode [M9M, ON, Canada]>
# 58 1 M1N <[OK] Geocodefarm - Geocode [M1N, ON, Canada]>
# 59 2 M2N <[OK] Geocodefarm - Geocode [M2N, ON, Canada]>
# 60 1 M3N <[OK] Geocodefarm - Geocode [M3N, ON, Canada]>
# 61 1 M4N <[OK] Geocodefarm - Geocode [M4N, ON, Canada]>
# 62 5 M5N <[OK] Geocodefarm - Geocode [M5N, ON, Canada]>
# 63 1 M6N <[OK] Geocodefarm - Geocode [M6N, ON, Canada]>
# 64 1 M9N <[OK] Geocodefarm - Geocode [M9N, ON, Canada]>
# 65 3 M1P <[OK] Geocodefarm - Geocode [M1P, ON, Canada]>
# 66 2 M2P <[OK] Geocodefarm - Geocode [M2P, ON, Canada]>
# 67 1 M4P <[OK] Geocodefarm - Geocode [M4P, ON, Canada]>
# 68 4 M5P <[OK] Geocodefarm - Geocode [M5P, ON, Canada]>
# 69 1 M6P <[OK] Geocodefarm - Geocode [M6P, ON, Canada]>
# 70 1 M9P <[OK] Geocodefarm - Geocode [M9P, ON, Canada]>
# 71 3 M1R <[OK] Geocodefarm - Geocode [M1R, ON, Canada]>
# 72 1 M2R <[OK] Geocodefarm - Geocode [M2R, ON, Canada]>
# 73 2 M4R <[OK] Geocodefarm - Geocode [M4R, ON, Canada]>
# 74 2 M5R <[OK] Geocodefarm - Geocode [M5R, ON, Canada]>
# 75 3 M6R <[OK] Geocodefarm - Geocode [M6R, ON, Canada]>
# 76 1 M7R <[OK] Geocodefarm - Geocode [Toronto, ON, Canada]>
# 77 3 M9R <[OK] Geocodefarm - Geocode [M9R, ON, Canada]>
# 78 1 M1S <[OK] Geocodefarm - Geocode [M1S, ON, Canada]>
# 79 2 M4S <[OK] Geocodefarm - Geocode [M4S, ON, Canada]>
# 80 1 M5S <[OK] Geocodefarm - Geocode [M5S, ON, Canada]>
# 81 6 M6S <[OK] Geocodefarm - Geocode [M6S, ON, Canada]>
# 82 1 M1T <[OK] Geocodefarm - Geocode [M1T, ON, Canada]>
# 83 1 M4T <[OK] Geocodefarm - Geocode [M4T, ON, Canada]>
# 84 3 M5T <[OK] Geocodefarm - Geocode [M5T, ON, Canada]>
# 85 2 M1V <[OK] Geocodefarm - Geocode [M1V, ON, Canada]>
# 86 1 M4V <[OK] Geocodefarm - Geocode [M4V, ON, Canada]>
# 87 1 M5V <[OK] Geocodefarm - Geocode [M5V, ON, Canada]>
# 88 2 M8V <[OK] Geocodefarm - Geocode [M8V, ON, Canada]>
# 89 1 M9V <[OK] Geocodefarm - Geocode [M9V, ON, Canada]>
# 90 4 M1W <[OK] Geocodefarm - Geocode [M1W, ON, Canada]>
# 91 1 M4W <[OK] Geocodefarm - Geocode [M4W, ON, Canada]>
# 92 1 M5W <[OK] Geocodefarm - Geocode [M5W, ON, Canada]>
# 93 1 M8W <[OK] Geocodefarm - Geocode [M8W, ON, Canada]>
# 94 6 M9W <[OK] Geocodefarm - Geocode [M9W, ON, Canada]>
# 95 6 M1X <[OK] Geocodefarm - Geocode [M1X, ON, Canada]>
# 96 1 M4X <[OK] Geocodefarm - Geocode [M4X, ON, Canada]>
# 97 5 M5X <[OK] Geocodefarm - Geocode [M5X, ON, Canada]>
# 98 3 M8X <[OK] Geocodefarm - Geocode [M8X, ON, Canada]>
# 99 4 M4Y <[OK] Geocodefarm - Geocode [M4Y, ON, Canada]>
# 100 1 M7Y <[OK] Geocodefarm - Geocode [Toronto, ON, Canada]>
# 101 1 M8Y <[OK] Geocodefarm - Geocode [M8Y, ON, Canada]>
# 102 1 M8Z <[OK] Geocodefarm - Geocode [M8Z, ON, Canada]>
#    Postcode           Borough  \
# 0       M3A        North York
# 1       M4A        North York
# 2       M5A  Downtown Toronto
# 3       M6A        North York
# 4       M7A      Queen's Park
# 5       M9A         Etobicoke
# 6       M1B       Scarborough
# 7       M3B        North York
# 8       M4B         East York
# 9       M5B  Downtown Toronto
# 10      M6B        North York
# 11      M9B         Etobicoke
# 12      M1C       Scarborough
# 13      M3C        North York
# 14      M4C         East York
# 15      M5C  Downtown Toronto
# 16      M6C              York
# 17      M9C         Etobicoke
# 18      M1E       Scarborough
# 19      M4E      East Toronto
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                           Parkwoods  43.751255 -79.329895
# 1                                    Victoria Village  43.729958 -79.314201
# 2                           Harbourfront, Regent Park  43.655220 -79.361969
# 3                    Lawrence Heights, Lawrence Manor  43.722801 -79.450691
# 4                                        Queen's Park  43.664486 -79.393021
# 5                                    Islington Avenue  43.662743 -79.528427
# 6                                      Rouge, Malvern  43.810154 -79.194603
# 7                                     Don Mills North  43.749134 -79.362007
# 8                     Woodbine Gardens, Parkview Hill  43.707577 -79.310913
# 9                            Ryerson, Garden District  43.657467 -79.377708
# 10                                          Glencairn  43.706573 -79.447830
# 11  Cloverdale, Islington, Martin Grove, Princess ...  43.650787 -79.550316
# 12             Highland Creek, Rouge Hill, Port Union  43.784672 -79.158958
# 13                   Flemingdon Park, Don Mills South  43.725864 -79.344620
# 14                                   Woodbine Heights  43.689819 -79.310364
# 15                                     St. James Town  43.651211 -79.375481
# 16                                 Humewood-Cedarvale  43.691833 -79.431625
# 17  Bloordale Gardens, Eringate, Markland Wood, Ol...  43.648396 -79.577545
# 18                  Guildwood, Morningside, West Hill  43.766289 -79.172890
# 19                                        The Beaches  43.679611 -79.295692

# %% [markdown]
# Backup plan -- import the latitude and the longitude coordinates of the Postcodes from

# %%
pcodes = pd.read_csv('Geospatial_Coordinates.csv')
pcodes.rename(columns={"Postal Code": "Postcode"}, inplace=True)
gdata = data1.merge(pcodes, on="Postcode")
gdata.head(20)
# Out:
#    Postcode           Borough  \
# 0       M3A        North York
# 1       M4A        North York
# 2       M5A  Downtown Toronto
# 3       M6A        North York
# 4       M7A      Queen's Park
# 5       M9A         Etobicoke
# 6       M1B       Scarborough
# 7       M3B        North York
# 8       M4B         East York
# 9       M5B  Downtown Toronto
# 10      M6B        North York
# 11      M9B         Etobicoke
# 12      M1C       Scarborough
# 13      M3C        North York
# 14      M4C         East York
# 15      M5C  Downtown Toronto
# 16      M6C              York
# 17      M9C         Etobicoke
# 18      M1E       Scarborough
# 19      M4E      East Toronto
#
#                                         Neighbourhood   Latitude  Longitude
# 0                                           Parkwoods  43.753259 -79.329656
# 1                                    Victoria Village  43.725882 -79.315572
# 2                           Harbourfront, Regent Park  43.654260 -79.360636
# 3                    Lawrence Heights, Lawrence Manor  43.718518 -79.464763
# 4                                        Queen's Park  43.662301 -79.389494
# 5                                    Islington Avenue  43.667856 -79.532242
# 6                                      Rouge, Malvern  43.806686 -79.194353
# 7                                     Don Mills North  43.745906 -79.352188
# 8                     Woodbine Gardens, Parkview Hill  43.706397 -79.309937
# 9                            Ryerson, Garden District  43.657162 -79.378937
# 10                                          Glencairn  43.709577 -79.445073
# 11  Cloverdale, Islington, Martin Grove, Princess ...  43.650943 -79.554724
# 12             Highland Creek, Rouge Hill, Port Union  43.784535 -79.160497
# 13                   Flemingdon Park, Don Mills South  43.725900 -79.340923
# 14                                   Woodbine Heights  43.695344 -79.318389
# 15                                     St. James Town  43.651494 -79.375418
# 16                                 Humewood-Cedarvale  43.693781 -79.428191
# 17  Bloordale Gardens, Eringate, Markland Wood, Ol...  43.643515 -79.577201
# 18                  Guildwood, Morningside, West Hill  43.763573 -79.188711
# 19                                        The Beaches  43.676357 -79.293031
